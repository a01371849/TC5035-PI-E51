# %% [markdown]
# # Proyecto Integrador (TC5035)
# # Identificación de Gestos en el Lenguaje de Manos Mexicano
# # Avance 4. Modelos alternativos
# ---
# ## EQUIPO 51
# - CARLOS MIGUEL ARVIZU DURÁN - A01410682
# - YOHANNA CEBALLOS SALOMÓN - A01795115
# - RUBÉN DÍAZ GARCÍA - A01371849
#
# ## Profesores
# - PROFESOR ASESOR: DR. RAÚL VALENTE RAMÍREZ VELARDE
# - PROFESORA TITULAR: DRA. GRETTEL BARCELÓ ALONSO
# - PROFESOR TITULAR: DR. LUIS EDUARDO FALCÓN MORALES
# - PROFESORA ASISTENTE: MTRA. VERÓNICA SANDRA GUZMÁN DE VALLE
#
# ---

# %% [markdown]
# # Modelo 4 MLP (Multilayer Perceptron)

# %% [markdown]
# **MLP (Multilayer Perceptron)**
#
#    Aunque no incorpora memoria ni convolución temporal, permite establecer una referencia sobre el desempeño que puede alcanzarse con una red densa estándar al usar la misma representación de entrada procesada (scaler + PCA).

# %% [markdown]
# ## Librerías

# %%
import os
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Flatten
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score, recall_score
# Out:
# 2025-10-19 22:40:25.172480: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-19 22:40:25.185333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760935225.199733   31162 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760935225.204827   31162 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760935225.215900   31162 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760935225.215926   31162 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760935225.215927   31162 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760935225.215928   31162 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-19 22:40:25.220082: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Carga de Datos

# %%
# CONFIGURACIÓN: se debe ajustar a la carpeta desde donde se corre el programa
notebook_dir = Path.cwd() 
current_script_dir = notebook_dir#.parent
parent_dir = current_script_dir
PROCESSED_DATA_DIR = parent_dir / "processed_data_pipeline"
data_dir = parent_dir / "data"
VIDEOS_DIR =  data_dir / "videos"

print(f"\nPaths: \nPROCESSED DATA DIRECTORY: {PROCESSED_DATA_DIR} \nVIDEOS DIRECTORY: {VIDEOS_DIR}")
# Out:
# Paths:
# PROCESSED DATA DIRECTORY: /mnt/d/Code/MNA/lsm/TC5035-PI-E51/Avance4/processed_data_pipeline
# VIDEOS DIRECTORY: /mnt/d/Code/MNA/lsm/TC5035-PI-E51/Avance4/data/videos

# %%
# --- Cargar los Datos Preprocesados ---
print("--- Cargando datos preprocesados ---")
X_train = np.load(os.path.join(PROCESSED_DATA_DIR, "X_train.npy"))
X_test = np.load(os.path.join(PROCESSED_DATA_DIR, "X_test.npy"))
y_train_df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR, "y_train.csv"))
y_test_df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR, "y_test.csv"))
y_train_labels = y_train_df['class'].values
y_test_labels = y_test_df['class'].values

print(f"Forma de X_train: {X_train.shape}")
print(f"Forma de X_test: {X_test.shape}\n")

# --- Codificar las Etiquetas ---
print("\n--- Codificando las etiquetas ---")
label_encoder = LabelEncoder()
all_labels = np.concatenate([y_train_labels, y_test_labels])
label_encoder.fit(all_labels)
y_train_encoded = label_encoder.transform(y_train_labels)
y_test_encoded = label_encoder.transform(y_test_labels)
num_classes = len(label_encoder.classes_)

# Dividimos los datos de entrenamiento para crear un conjunto de validación
# Usaremos el 15% de los datos de entrenamiento para validación
X_train, X_val, y_train_encoded, y_val_encoded = train_test_split(
    X_train, 
    y_train_encoded, 
    test_size=0.15, # 15% para validación
    random_state=42,
    stratify=y_train_encoded # Mantiene la proporción de clases
)

y_train_categorical = to_categorical(y_train_encoded, num_classes=num_classes)
y_val_categorical = to_categorical(y_val_encoded)
y_test_categorical = to_categorical(y_test_encoded, num_classes=num_classes)
print(f"Número de clases únicas: {num_classes}")
# Out:
# --- Cargando datos preprocesados ---
# Forma de X_train: (164, 150, 5)
# Forma de X_test: (41, 150, 5)
#
#
# --- Codificando las etiquetas ---
# Número de clases únicas: 4

# %% [markdown]
# ## Modelo 4 MLP (Multilayer Perceptron)

# %%
# --- Construir el Modelo ---
print("\n--- Construyendo la arquitectura del modelo MLP ---")
model = Sequential([
    # Esta capa aplana la entrada de (150, 5) a un vector de 750
    Flatten(input_shape=(X_train.shape[1], X_train.shape[2])),
    # Capa densa (oculta) con 128 neuronas y activación ReLU
    Dense(128, activation='relu'),
    # Capa de Dropout para prevenir el sobreajuste
    Dropout(0.5),
    # Otra capa densa (oculta)
    Dense(64, activation='relu'),
    Dropout(0.5),
    # Capa de salida con una neurona por clase y activación softmax
    Dense(y_train_categorical.shape[1], activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
model.summary()
# Out:
# --- Construyendo la arquitectura del modelo MLP ---
# /home/raven/miniconda3/envs/lsm/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1760935227.341137   31162 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 750)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        96,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,644 (408.77 KB)
#  Trainable params: 104,644 (408.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Entrenamiento

# %%
history = model.fit(X_train, y_train_categorical,
                        epochs=50,
                        batch_size=32,
                        validation_data=(X_val, y_val_categorical),
                        verbose=1)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760935255.416610   31295 service.cc:152] XLA service 0x70eb2c00cfc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760935255.416933   31295 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-10-19 22:40:55.455474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1760935255.609417   31295 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.1875 - loss: 3.7206
# I0000 00:00:1760935257.109562   31295 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.2953 - loss: 2.9693
# 2025-10-19 22:40:59.035670: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_62', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-19 22:40:59.107112: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_62', 4 bytes spill stores, 4 bytes spill loads
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 582ms/step - accuracy: 0.3957 - loss: 2.4650 - val_accuracy: 0.8400 - val_loss: 0.4424
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7482 - loss: 1.0101 - val_accuracy: 0.9200 - val_loss: 0.2679
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7482 - loss: 0.8117 - val_accuracy: 0.9600 - val_loss: 0.1901
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7914 - loss: 0.6793 - val_accuracy: 0.9600 - val_loss: 0.1743
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8273 - loss: 0.4625 - val_accuracy: 0.9600 - val_loss: 0.1563
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8921 - loss: 0.3531 - val_accuracy: 0.9600 - val_loss: 0.1333
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9137 - loss: 0.2625 - val_accuracy: 0.9600 - val_loss: 0.1095
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9281 - loss: 0.1981 - val_accuracy: 0.9600 - val_loss: 0.0887
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9353 - loss: 0.1841 - val_accuracy: 0.9600 - val_loss: 0.0762
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9065 - loss: 0.1821 - val_accuracy: 0.9600 - val_loss: 0.0610
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9424 - loss: 0.2252 - val_accuracy: 0.9600 - val_loss: 0.0580
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8993 - loss: 0.2219 - val_accuracy: 0.9600 - val_loss: 0.0667
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9640 - loss: 0.1108 - val_accuracy: 0.9600 - val_loss: 0.0784
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.9496 - loss: 0.1430 - val_accuracy: 0.9600 - val_loss: 0.0921
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9209 - loss: 0.1910 - val_accuracy: 0.9600 - val_loss: 0.0850
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ -7s 16ms/step - accuracy: 0.9568 - loss: 0.1100 - val_accuracy: 0.9600 - val_loss: 0.0701
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9568 - loss: 0.0954 - val_accuracy: 0.9600 - val_loss: 0.0703
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9568 - loss: 0.1169 - val_accuracy: 0.9600 - val_loss: 0.0717
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9784 - loss: 0.0758 - val_accuracy: 0.9600 - val_loss: 0.0658
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9928 - loss: 0.0386 - val_accuracy: 0.9600 - val_loss: 0.0566
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9496 - loss: 0.1172 - val_accuracy: 0.9600 - val_loss: 0.0488
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0526 - val_accuracy: 0.9600 - val_loss: 0.0483
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.9600 - val_loss: 0.0514
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9784 - loss: 0.0632 - val_accuracy: 0.9600 - val_loss: 0.0460
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0478 - val_accuracy: 0.9600 - val_loss: 0.0412
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9784 - loss: 0.0517 - val_accuracy: 0.9600 - val_loss: 0.0414
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9856 - loss: 0.0321 - val_accuracy: 0.9600 - val_loss: 0.0382
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0455 - val_accuracy: 0.9600 - val_loss: 0.0416
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9712 - loss: 0.0333 - val_accuracy: 0.9600 - val_loss: 0.0456
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0138 - val_accuracy: 0.9600 - val_loss: 0.0494
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9600 - val_loss: 0.0494
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9856 - loss: 0.0521 - val_accuracy: 0.9600 - val_loss: 0.0571
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9784 - loss: 0.0564 - val_accuracy: 0.9600 - val_loss: 0.0630
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0239 - val_accuracy: 0.9600 - val_loss: 0.0665
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9856 - loss: 0.0258 - val_accuracy: 0.9600 - val_loss: 0.0631
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9600 - val_loss: 0.0528
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9928 - loss: 0.0239 - val_accuracy: 0.9600 - val_loss: 0.0459
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9856 - loss: 0.0250 - val_accuracy: 0.9600 - val_loss: 0.0411
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9856 - loss: 0.0647 - val_accuracy: 0.9600 - val_loss: 0.0394
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9856 - loss: 0.0344 - val_accuracy: 0.9600 - val_loss: 0.0411
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9600 - val_loss: 0.0351
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9856 - loss: 0.0354 - val_accuracy: 0.9600 - val_loss: 0.0307
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9856 - loss: 0.0406 - val_accuracy: 0.9600 - val_loss: 0.0294
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9600 - val_loss: 0.0310
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9784 - loss: 0.0665 - val_accuracy: 0.9600 - val_loss: 0.0341
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9928 - loss: 0.0281 - val_accuracy: 0.9600 - val_loss: 0.0310
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0265
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9928 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9928 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 0.0184

# %% [markdown]
# ## Resultado

# %%
# --- Evaluar y Visualizar los Resultados ---
print("\n--- Evaluando el modelo con métricas detalladas ---")

# Realizar predicciones en el conjunto de prueba
y_pred_probabilities = model.predict(X_test)
# Convertir las probabilidades a etiquetas de clase predichas (la de mayor probabilidad)
y_pred_encoded = np.argmax(y_pred_probabilities, axis=1)
# Out:
# --- Evaluando el modelo con métricas detalladas ---
# 2025-10-19 22:41:04.297421: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-10-19 22:41:04.350267: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17', 4 bytes spill stores, 4 bytes spill loads
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 636ms/step

# %%
# Generar y mostrar el Reporte de Clasificación
print("\n--- Reporte de Clasificación ---")
# Reporte: precisión, recall y f1-score para cada clase.
report = classification_report(y_test_encoded, y_pred_encoded, target_names=label_encoder.classes_)
print(report)

# Accuracy (Precisión Global)
accuracy = accuracy_score(y_test_encoded, y_pred_encoded)
print(f"La precisión (accuracy) del modelo es: {accuracy:.2f}")

# Recall
recall = recall_score(y_test_encoded, y_pred_encoded, average='weighted')
print(f"El recall (weighted) del modelo es: {recall:.2f}")

# F1-score
f1 = f1_score(y_test_encoded, y_pred_encoded, average='weighted')
print(f"El F1-score (weighted) del modelo es: {f1:.2f}")
# Out:
# --- Reporte de Clasificación ---
#               precision    recall  f1-score   support
#
#        Abrir       1.00      1.00      1.00        10
#       Avión       1.00      0.90      0.95        10
#       Borrar       0.92      1.00      0.96        11
#           Tu       1.00      1.00      1.00        10
#
#     accuracy                           0.98        41
#    macro avg       0.98      0.97      0.98        41
# weighted avg       0.98      0.98      0.98        41
#
# La precisión (accuracy) del modelo es: 0.98
# El recall (weighted) del modelo es: 0.98
# El F1-score (weighted) del modelo es: 0.98

# %%
# Generar y mostrar la Matriz de Confusión
print("\n--- Matriz de Confusión ---")
cm = confusion_matrix(y_test_encoded, y_pred_encoded)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', 
            xticklabels=label_encoder.classes_, 
            yticklabels=label_encoder.classes_)
plt.title('Matriz de Confusión MLP', fontsize=16)
plt.ylabel('Clase Real', fontsize=12)
plt.xlabel('Clase Predicha', fontsize=12)
plt.show()
# Out:
# --- Matriz de Confusión ---

# %%
# Graficar la precisión y la pérdida durante el entrenamiento
print("\n--- Gráfica de precisión y pérdida durante el entrenamiento ---")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
# Gráfica de Precisión
ax1.plot(history.history['accuracy'], label='Precisión de Entrenamiento')
ax1.plot(history.history['val_accuracy'], label='Precisión de Validación')
ax1.set_title('Precisión del Modelo')
ax1.set_xlabel('Época')
ax1.set_ylabel('Precisión')
ax1.legend()
ax1.grid(True)
# Gráfica de Pérdida
ax2.plot(history.history['loss'], label='Pérdida de Entrenamiento')
ax2.plot(history.history['val_loss'], label='Pérdida de Validación')
ax2.set_title('Pérdida del Modelo')
ax2.set_xlabel('Época')
ax2.set_ylabel('Pérdida')
ax2.legend()
ax2.grid(True)
plt.suptitle('Historial de Entrenamiento del Modelo MLP', fontsize=16)
plt.show()

print("\nEntrenamiento completado!")
# Out:
# --- Gráfica de precisión y pérdida durante el entrenamiento ---
# Entrenamiento completado!
